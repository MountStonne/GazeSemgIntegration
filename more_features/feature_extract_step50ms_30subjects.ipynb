# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks/Research/GazeSemgIntegration/more_features
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/Research/GazeSemgIntegration/more_features

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from sklearn.svm import LinearSVC,SVC
from sklearn.neighbors import KNeighborsClassifier
import lightgbm as ltb
from sklearn.neural_network import MLPClassifier
from copy import deepcopy
import warnings
import math


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

warnings.filterwarnings('ignore')

# %%
subject_number = 17

# static_end = []
# for i in tqdm(range(10,10+subject_number)):
#     current_dynamic = pd.read_csv('data_all_intact/S0' + str(i) + '_dynamic.csv', header=None)

#     for j in range(len(current_dynamic)-1, -1, -1):
#         if current_dynamic.iloc[j,0] == 0:
#             static_end.append(j)
#             break


# static_end_df = pd.DataFrame(static_end)
# static_end_df.to_csv('featured_data/all_intact_featured_step50ms/static_end.csv', index=False)

# %%
static_end_df = pd.read_csv('featured_data/all_intact_featured_step50ms/static_end.csv')
static_end = static_end_df.to_numpy().flatten()

# %% [markdown]
# # STD

# %%
# index variable
'''change name, features'''
name = 'STD'

# start
for i in tqdm(range(24,24+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(trainx_raw.iloc[a-385:a+1, b].std())
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(testx_raw.iloc[a-385:a+1,b].std())
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')
# Out:
# 'change name, features'
# HBox(children=(FloatProgress(value=0.0, max=17.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6230528.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19568.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6144.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5413137.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16917.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5423.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6232635.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6175.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6217891.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19467.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6166.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6240541.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19580.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6184.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6232525.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19559.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6150.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6236565.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19572.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6173.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6228418.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19536.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6159.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5411845.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16918.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5430.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6242094.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19580.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6170.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6350288.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19862.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6288.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5411180.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16875.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5450.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6090203.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19052.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6009.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5431634.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16974.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5438.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5409351.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16933.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5410.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5421368.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=17008.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5407.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6226541.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=19554.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6144.0), HTML(value='')))

# %% [markdown]
# # RMS

# %%
def rms(self):
    current =0
    square =0
    for i in range(0, len(self)):
        current = self.iloc[i]
        square += current ** 2
    mean = square/len(self)
    root = math.sqrt(mean)
    return root

# index variable
'''change name, features'''
name = 'RMS'

# start
for i in tqdm(range(10,10+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(rms(trainx_raw.iloc[a-385:a+1, b]))
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(rms(testx_raw.iloc[a-385:a+1, b]))
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')

# %% [markdown]
# # IEMG

# %%
def iemg(self):
    current =0
    absolute =0
    for i in range(0, len(self)):
        current = self.iloc[i]
        absolute += np.abs(current)
    return absolute

# index variable
'''change name, features'''
name = 'IEMG'

# start
for i in tqdm(range(10,10+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(iemg(trainx_raw.iloc[a-385:a+1, b]))
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(iemg(testx_raw.iloc[a-385:a+1, b]))
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')

# %% [markdown]
# # MAV

# %%
def mav(self):
    current =0
    absolute =0
    for i in range(0, len(self)):
        current = self.iloc[i]
        absolute += np.abs(current)
    return absolute/len(self)

# index variable
'''change name, features'''
name = 'MAV'

# start
for i in tqdm(range(10,10+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(mav(trainx_raw.iloc[a-385:a+1, b]))
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(mav(testx_raw.iloc[a-385:a+1, b]))
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')

# %% [markdown]
# # WL

# %%
def wl(self):
    current =0
    diff =0
    for i in range(1, len(self)):
        current = self.iloc[i]
        diff += np.abs(current - self.iloc[i-1])
    return diff

# index variable
'''change name, features'''
name = 'WL'

# start
for i in tqdm(range(10,10+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(wl(trainx_raw.iloc[a-385:a+1, b]))
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(wl(testx_raw.iloc[a-385:a+1, b]))
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')

# %% [markdown]
# # SSI

# %%
def ssi(self):
    current =0
    square = 0
    for i in range(0, len(self)):
        current = self.iloc[i]
        square += current ** 2
    return square

# index variable
'''change name, features'''
name = 'SSI'

# start
for i in tqdm(range(10,10+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(ssi(trainx_raw.iloc[a-385:a+1, b]))
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(ssi(testx_raw.iloc[a-385:a+1, b]))
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')

# %% [markdown]
# # AAC

# %%
def aac(self):
    current =0
    diff =0
    for i in range(1, len(self)):
        current = self.iloc[i]
        diff += np.abs(current - self.iloc[i-1])
    return diff/len(self)

# index variable
'''change name, features'''
name = 'AAC'

# start
for i in tqdm(range(10,10+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(aac(trainx_raw.iloc[a-385:a+1, b]))
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(aac(testx_raw.iloc[a-385:a+1, b]))
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')

# %% [markdown]
# # DASDV

# %%
def dasdv(self):
    current =0
    square =0
    for i in range(1, len(self)):
        current = self.iloc[i]
        square += (current - self.iloc[i-1])**2
    return square/(len(self)-1)

# index variable
'''change name, features'''
name = 'DASDV'

# start
for i in tqdm(range(10,10+subject_number)):
    
    # read csv files
    current_emg = pd.read_csv('data_all_intact/S0' + str(i) + '_emg.csv', header=None)
    current_grasp = pd.read_csv('data_all_intact/S0' + str(i) + '_grasp.csv', header=None)
    current_grasprepetition = pd.read_csv('data_all_intact/S0' + str(i) + '_grasprepetition.csv', header=None)
    
    current_static_emg = current_emg.iloc[0:static_end[i-10]]
    current_static_grasp = current_grasp.iloc[0:static_end[i-10]]
    current_static_grasprepetition = current_grasprepetition.iloc[0:static_end[i-10]]
    
    # find raw train/test data
    train_index = []
    test_index = []
    for j in tqdm(range(len(current_static_grasprepetition))):
        if current_static_grasprepetition.iloc[j,0] in [1,2,3,4,5,6,7,8,9]:
            train_index.append(j)
        if current_static_grasprepetition.iloc[j,0] in [10,11,12]:
            test_index.append(j)
    
    trainx_raw = current_static_emg.iloc[train_index].reset_index(drop=True)
    trainy_raw = current_static_grasp.iloc[train_index].reset_index(drop=True)

    testx_raw = current_static_emg.iloc[test_index].reset_index(drop=True)
    testy_raw = current_static_grasp.iloc[test_index].reset_index(drop=True)
    
    # add overlapping window to train/test data
    ## 385 means the overlapping window is 200ms
    ## train data

    trainx = []
    trainy = []
    
    for a in tqdm(range(385,len(trainx_raw), 96)):
        current_row = []
        for b in range(0,len(trainx_raw.columns)):
            current_row.append(dasdv(trainx_raw.iloc[a-385:a+1, b]))
        trainx.append(current_row)
        trainy.append(trainy_raw.iloc[a, 0])

    ## test data
    testx = []
    testy = []

    for a in tqdm(range(385,len(testx_raw),96)):
        current_row = []
        for b in range(0,len(testx_raw.columns)):
            current_row.append(dasdv(testx_raw.iloc[a-385:a+1, b]))
        testx.append(current_row)
        testy.append(testy_raw.iloc[a, 0])
    
    trainx_df = pd.DataFrame(trainx)
    trainy_df = pd.DataFrame(trainy)
    testx_df = pd.DataFrame(testx)
    testy_df = pd.DataFrame(testy)

    trainx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainx.csv')
    trainy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_trainy.csv')
    testx_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testx.csv')
    testy_df.to_csv('featured_data/all_intact_featured_step50ms/S0' + str(i) + '/' + name + '_testy.csv')

# %% [markdown]
# # Debug

# %%
emg = pd.read_csv('data_all_intact/S024_emg.csv', header=None)

# %%
len(emg.columns)
# Out:
# 11
